# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Avaliação dos resultados

# %%
df = pd.read_csv('../output/methods_result_2.csv', sep=',')
df['method'] = df['method'].replace({
    'Bissection': 'Bissecção',
    'False Position': 'Falsa Posição',
    'Fixed Point': 'Ponto Fixo',
    'Newton Raphson': 'Newton-Raphson',
    'Secant': 'Secante'
})
df.head()
# Out:
#    root_index    xl       xu        x  relative_error     tol  iter  \
# 0           0  1.80  2.10000  1.80000       16.666667  0.0001     1
# 1           0  1.95  2.10000  1.95000        7.692308  0.0001     2
# 2           0  1.95  2.02500  2.02500        3.703704  0.0001     3
# 3           0  1.95  1.98750  1.98750        1.886792  0.0001     4
# 4           0  1.95  1.96875  1.96875        0.952381  0.0001     5
#
#            function     method
# 0  (x/2) - tan(2*x)  Bissecção
# 1  (x/2) - tan(2*x)  Bissecção
# 2  (x/2) - tan(2*x)  Bissecção
# 3  (x/2) - tan(2*x)  Bissecção
# 4  (x/2) - tan(2*x)  Bissecção

# %% [markdown]
# ### 1ª raiz

# %%
df_1 = df[(df['function'] == '(x/2) - tan(2*x)') & (df['root_index'] == 0) & (df['iter'] <= 100)]
df_1 = df_1[(df_1['method'] != 'Ponto Fixo')]

fig = plt.figure(figsize=(10, 6))
sns.lineplot(data=df_1, x='iter', y='relative_error', hue='method', palette='Set1')
plt.title('Convergência dos métodos para f(x) = (x/2) - tan(2*x)')
plt.xlabel('Iteração', fontsize=14)
plt.xticks(fontsize=12)
plt.ylabel('Erro estimado relativo (%)', fontsize=14)
plt.legend(title='Método', loc='upper right', fontsize=11, title_fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### 2ª Raiz

# %%
df_1 = df[(df['function'] == '(x/2) - tan(2*x)') & (df['root_index'] == 1) & (df['iter'] <= 100)]
df_1 = df_1[(df_1['method'] != 'Ponto Fixo')]

fig = plt.figure(figsize=(10, 6))
sns.lineplot(data=df_1, x='iter', y='relative_error', hue='method', palette='Set1')
plt.title('Convergência dos métodos para f(x) = (x/2) - tan(2*x)')
plt.xlabel('Iteração', fontsize=14)
plt.xticks(fontsize=12)
plt.ylabel('Erro estimado relativo (%)', fontsize=14)
plt.legend(title='Método', loc='upper right', fontsize=11, title_fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### 3ª Raiz

# %%
df_1 = df[(df['function'] == '(x/2) - tan(2*x)') & (df['root_index'] == 2) & (df['iter'] <= 100)]
df_1 = df_1[(df_1['method'] != 'Ponto Fixo')]
#df_1 = df_1[(df_1['method'] != 'Secante')]

fig = plt.figure(figsize=(10, 6))
sns.lineplot(data=df_1, x='iter', y='relative_error', hue='method', palette='Set1')
plt.title('Convergência dos métodos para f(x) = (x/2) - tan(2*x)')
plt.xlabel('Iteração', fontsize=14)
plt.xticks(fontsize=12)
plt.ylabel('Erro estimado relativo (%)', fontsize=14)
plt.legend(title='Método', loc='upper right', fontsize=11, title_fontsize=12)
plt.yscale('log')
plt.show()

# %% [markdown]
# ### 4ª Raiz

# %%
df_1 = df[(df['function'] == '(x/2) - tan(2*x)') & (df['root_index'] == 3) & (df['iter'] <= 100)]
df_1 = df_1[(df_1['method'] != 'Ponto Fixo')]
#df_1 = df_1[(df_1['method'] != 'Secante')]

fig = plt.figure(figsize=(10, 6))
sns.lineplot(data=df_1, x='iter', y='relative_error', hue='method', palette='Set1')
plt.title('Convergência dos métodos para f(x) = (x/2) - tan(2*x)')
plt.xlabel('Iteração', fontsize=14)
plt.xticks(fontsize=12)
plt.ylabel('Erro estimado relativo (%)', fontsize=14)
plt.legend(title='Método', loc='upper right', fontsize=11, title_fontsize=12)
plt.show()

# %% [markdown]
# ### 5ª Raiz

# %%
df_1 = df[(df['function'] == '(x/2) - tan(2*x)') & (df['root_index'] == 4) & (df['iter'] <= 100)]
df_1 = df_1[(df_1['method'] != 'Ponto Fixo')]
#df_1 = df_1[(df_1['method'] != 'Secante')]

fig = plt.figure(figsize=(10, 6))
sns.lineplot(data=df_1, x='iter', y='relative_error', hue='method', palette='Set1')
plt.title('Convergência dos métodos para f(x) = (x/2) - tan(2*x)')
plt.xlabel('Iteração', fontsize=14)
plt.xticks(fontsize=12)
plt.ylabel('Erro estimado relativo (%)', fontsize=14)
plt.legend(title='Método', loc='upper right', fontsize=11, title_fontsize=12)
plt.yscale('log')
plt.show()
